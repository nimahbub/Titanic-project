# %%
#importing library
import pandas as pd
import numpy as np
import os

# %%
#Loading data as csv file
train_df=pd.read_csv("train.csv",index_col="PassengerId")
test_df=pd.read_csv("test.csv",index_col="PassengerId")

# %% [markdown]
# # Data Organization Part

# %%
#get the type
type(train_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Basic Strucute

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
# Pclass      418 non-null int64
# Name        418 non-null object
# Sex         418 non-null object
# Age         332 non-null float64
# SibSp       418 non-null int64
# Parch       418 non-null int64
# Ticket      418 non-null object
# Fare        417 non-null float64
# Cabin       91 non-null object
# Embarked    418 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %%
# as survived column not present in test data so add this with default value
test_df['Survived']=-888 #adding with any value

# %%
test_df
# Out:
#              Pclass                                               Name  \
# PassengerId
# 892               3                                   Kelly, Mr. James
# 893               3                   Wilkes, Mrs. James (Ellen Needs)
# 894               2                          Myles, Mr. Thomas Francis
# 895               3                                   Wirz, Mr. Albert
# 896               3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 897               3                         Svensson, Mr. Johan Cervin
# 898               3                               Connolly, Miss. Kate
# 899               2                       Caldwell, Mr. Albert Francis
# 900               3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 901               3                            Davies, Mr. John Samuel
# 902               3                                   Ilieff, Mr. Ylio
# 903               1                         Jones, Mr. Charles Cresson
# ...

# %%
#concating train and test data set
df=pd.concat((train_df,test_df),axis=0)  #axis=0 means concat column wise
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
df.tail(10)
# Out:
#               Age Cabin Embarked      Fare  \
# PassengerId
# 1300          NaN   NaN        Q    7.7208
# 1301          3.0   NaN        S   13.7750
# 1302          NaN   NaN        Q    7.7500
# 1303         37.0   C78        Q   90.0000
# 1304         28.0   NaN        S    7.7750
# 1305          NaN   NaN        S    8.0500
# 1306         39.0  C105        C  108.9000
# 1307         38.5   NaN        S    7.2500
# 1308          NaN   NaN        S    8.0500
# 1309          NaN   NaN        C   22.3583
#
#                                                         Name  Parch  Pclass  \
# PassengerId
# 1300                         Riordan, Miss. Johanna Hannah""      0       3
# 1301                               Peacock, Miss. Treasteall      1       3
# 1302                                  Naughton, Miss. Hannah      0       3
# 1303         Minahan, Mrs. William Edward (Lillian E Thorpe)      0       1
# 1304                          Henriksson, Miss. Jenny Lovisa      0       3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1307 non-null object
# Fare        1308 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 122.7+ KB

# %% [markdown]
# # Selection,Indexing and Filtering using pandas

# %%
#selecting column
df['Name']
# Out:
# PassengerId
# 1                                 Braund, Mr. Owen Harris
# 2       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                  Heikkinen, Miss. Laina
# 4            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                Allen, Mr. William Henry
# 6                                        Moran, Mr. James
# 7                                 McCarthy, Mr. Timothy J
# 8                          Palsson, Master. Gosta Leonard
# 9       Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                    Nasser, Mrs. Nicholas (Adele Achem)
# 11                        Sandstrom, Miss. Marguerite Rut
# 12                               Bonnell, Miss. Elizabeth
# 13                         Saundercock, Mr. William Henry
# 14                            Andersson, Mr. Anders Johan
# 15                   Vestrom, Miss. Hulda Amanda Adolfina
# 16                       Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
#selectinng multiple columns using a list of column name
df[['Name','Age']]
# Out:
#                                                           Name   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3                                       Heikkinen, Miss. Laina  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5                                     Allen, Mr. William Henry  35.0
# 6                                             Moran, Mr. James   NaN
# 7                                      McCarthy, Mr. Timothy J  54.0
# 8                               Palsson, Master. Gosta Leonard   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 11                             Sandstrom, Miss. Marguerite Rut   4.0
# 12                                    Bonnell, Miss. Elizabeth  58.0
# ...

# %% [markdown]
# ## Label based Indexing: loc is used for label based indexing
# - before comma(,) specifed rows and after comma(,) specified column

# %%
df.loc[5:10,]# here selecting 5-10 rows and all columns
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 5            35.0   NaN        S   8.0500
# 6             NaN   NaN        Q   8.4583
# 7            54.0   E46        S  51.8625
# 8             2.0   NaN        S  21.0750
# 9            27.0   NaN        S  11.1333
# 10           14.0   NaN        C  30.0708
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 5                                     Allen, Mr. William Henry      0       3
# 6                                             Moran, Mr. James      0       3
# 7                                      McCarthy, Mr. Timothy J      0       1
# 8                               Palsson, Master. Gosta Leonard      1       3
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2       3
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      0       2
#
#                 Sex  SibSp  Survived  Ticket
# PassengerId
# ...

# %%
df.loc[5:10,'Age':'Name'] #selecting 5-10 rows and Age-Name
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 5            35.0   NaN        S   8.0500
# 6             NaN   NaN        Q   8.4583
# 7            54.0   E46        S  51.8625
# 8             2.0   NaN        S  21.0750
# 9            27.0   NaN        S  11.1333
# 10           14.0   NaN        C  30.0708
#
#                                                           Name
# PassengerId
# 5                                     Allen, Mr. William Henry
# 6                                             Moran, Mr. James
# 7                                      McCarthy, Mr. Timothy J
# 8                               Palsson, Master. Gosta Leonard
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                         Nasser, Mrs. Nicholas (Adele Achem)

# %%
#For discrete column
df.loc[5:10,['Age','Fare','Embarked']]
# Out:
#               Age     Fare Embarked
# PassengerId
# 5            35.0   8.0500        S
# 6             NaN   8.4583        Q
# 7            54.0  51.8625        S
# 8             2.0  21.0750        S
# 9            27.0  11.1333        S
# 10           14.0  30.0708        C

# %% [markdown]
#  ## Position based Indexing: used iloc for position based indexing

# %%
df.iloc[5:10,3:8]
# Out:
#                 Fare                                               Name  \
# PassengerId
# 6             8.4583                                   Moran, Mr. James
# 7            51.8625                            McCarthy, Mr. Timothy J
# 8            21.0750                     Palsson, Master. Gosta Leonard
# 9            11.1333  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10           30.0708                Nasser, Mrs. Nicholas (Adele Achem)
#
#              Parch  Pclass     Sex
# PassengerId
# 6                0       3    male
# 7                0       1    male
# 8                1       3    male
# 9                2       3  female
# 10               0       2  female

# %% [markdown]
# ## Filtering

# %%
#filter row based on condition
male_passenger=df.loc[df['Sex']=='male',]
print("Number of male passenger: ",len(male_passenger))
# Out:
# Number of male passenger:  843

# %%
#For complex operation use & or | operator
#Finding male passenger and travel in first class
male_passenger_first_class=df.loc[(df['Sex']=='male') & (df['Pclass']==1),]
print("Number male passenger in first class {}".format(len(male_passenger_first_class)))
# Out:
# Number male passenger in first class 179

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#                Age         Fare        Parch       Pclass        SibSp  \
# count  1046.000000  1308.000000  1309.000000  1309.000000  1309.000000
# mean     29.881138    33.295479     0.385027     2.294882     0.498854
# std      14.413493    51.758668     0.865560     0.837836     1.041658
# min       0.170000     0.000000     0.000000     1.000000     0.000000
# 25%      21.000000     7.895800     0.000000     2.000000     0.000000
# 50%      28.000000    14.454200     0.000000     3.000000     0.000000
# 75%      39.000000    31.275000     0.000000     3.000000     1.000000
# max      80.000000   512.329200     9.000000     3.000000     8.000000
#
#           Survived
# count  1309.000000
# mean   -283.301757
# std     414.337413
# min    -888.000000
# 25%    -888.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
#numerial feature 
#centrality measure
print('Mean fare: {}'.format(df['Fare'].mean()))
print('Median fare: {}'.format(df['Fare'].median()))
# Out:
# Mean fare: 33.2954792813456
# Median fare: 14.4542

# %%
#disperation measure
print('Min Fare: {}'.format(df['Fare'].min()))
print("Max Fare: {}".format(df['Fare'].max()))
print("Range Fare: {}".format((df['Fare'].max())-df['Fare'].min()))
print('25 percentile: {}'.format(df['Fare'].quantile(.25)))
print('50 percentile: {}'.format(df['Fare'].quantile(.5)))
print('75 percentile: {}'.format(df['Fare'].quantile(.75)))
print('Variance fare: {}'.format(df['Fare'].var()))
print("Standard deviation fare:{}".format(df['Fare'].std()))
# Out:
# Min Fare: 0.0
# Max Fare: 512.3292
# Range Fare: 512.3292
# 25 percentile: 7.8958
# 50 percentile: 14.4542
# 75 percentile: 31.275
# Variance fare: 2678.959737892894
# Standard deviation fare:51.75866823917414

# %%
# %matplotlib inline

# %%
#box-whisker plot
df['Fare'].plot(kind='box')

# %% [markdown]
# # For Categorial Feature

# %%
df.describe(include='all')
# Out:
#                 Age        Cabin Embarked         Fare                  Name  \
# count   1046.000000          295     1307  1308.000000                  1309
# unique          NaN          186        3          NaN                  1307
# top             NaN  C23 C25 C27        S          NaN  Connolly, Miss. Kate
# freq            NaN            6      914          NaN                     2
# mean      29.881138          NaN      NaN    33.295479                   NaN
# std       14.413493          NaN      NaN    51.758668                   NaN
# min        0.170000          NaN      NaN     0.000000                   NaN
# 25%       21.000000          NaN      NaN     7.895800                   NaN
# 50%       28.000000          NaN      NaN    14.454200                   NaN
# 75%       39.000000          NaN      NaN    31.275000                   NaN
# max       80.000000          NaN      NaN   512.329200                   NaN
#
# ...

# %%
#categorial column :Counts
df['Sex'].value_counts()
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
#categorial column:Proportions
df['Sex'].value_counts(normalize=True)
# Out:
# male      0.644003
# female    0.355997
# Name: Sex, dtype: float64

# %%
#apply on other columns
df[df.Survived !=-888].Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
df.Pclass.value_counts().plot(kind='bar')

# %%
#title:to set title,color:to set color,rot:to rote label
df.Pclass.value_counts().plot(kind='bar',rot=0,title='Class wise passenger count',color='c')

# %% [markdown]
# # Distributions

# %%
#Histogram
df['Age'].plot(kind='hist',title='histogram for age',color='c')

# %%
#histrogram for custom bin
df.Age.plot(kind='hist',title='Histogram for age',bins=20)

# %%
#KDE plot
df.Age.plot(kind='kde',title='Density plot for Age',color='c')

# %%
#Histogram for fare
df.Fare.plot(kind='hist',title='histogram for Fare',color='c',bins=20)

# %%
print('Skewness for age: {0:.2f}'.format(df.Age.skew()))
print('Skewness for fare: {0:.2f}'.format(df.Fare.skew()))
# Out:
# Skewness for age: 0.41
# Skewness for fare: 4.37

# %%
#use scatter plot for bi-variate distribution
df.plot.scatter(x='Age',y='Fare',color='c',title='scatter plot: Age vs Fare')

# %%
#use alpha to set the transparency
df.plot.scatter(x='Age',y='Fare',color='c',title='scatter plot: Age vs Fare',alpha=.1)

# %%
df.plot.scatter(x='Pclass',y='Fare',color='c',title='scatter plot: Pclass vs Fare',alpha=.15)

# %% [markdown]
# # Grouping and Aggregations

# %% [markdown]
# ## Problem:group the sex column and finding the age mean,median,count

# %%
#group by
#df.groupby(['Sex']).Age.mean()
df.groupby(['Sex']).Age.median()
#df.groupby(['Sex']).Age.count()
# Out:
# Sex
# female    27.0
# male      28.0
# Name: Age, dtype: float64

# %% [markdown]
# - grouping basex on Pclass and find median of Fare and Age

# %%
df.groupby(['Pclass']).Fare.median()
# Out:
# Pclass
# 1    60.0000
# 2    15.0458
# 3     8.0500
# Name: Fare, dtype: float64

# %%
df.groupby(['Pclass']).Age.median()
# Out:
# Pclass
# 1    39.0
# 2    29.0
# 3    24.0
# Name: Age, dtype: float64

# %%
#with together 
df.groupby(['Pclass'])['Fare','Age'].median()
# Out:
#            Fare   Age
# Pclass
# 1       60.0000  39.0
# 2       15.0458  29.0
# 3        8.0500  24.0

# %%
#for different aggregration
df.groupby(['Pclass']).agg({'Fare':'mean','Age':'median'})
# Out:
#              Fare   Age
# Pclass
# 1       87.508992  39.0
# 2       21.179196  29.0
# 3       13.302889  24.0

# %%
#more complicated aggregations
aggregations={
    'Fare':{#work on the 'Fare' column
        'mean_Fare':'mean',
        'median_Fare':'median',
        'max_Fare':max,
        'min_Fare':np.min
    },
    'Age':{#work on the 'Age' column
        
        'median_Age':'median',
        'min_Age':min,
        'max_Age':max,
        'range_Age':lambda x:max(x)-min(x)
    }
    
}

# %%
df.groupby(['Pclass']).agg(aggregations)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py:1315: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#              Fare                                       Age                  \
#         mean_Fare median_Fare  max_Fare min_Fare median_Age min_Age max_Age
# Pclass
# 1       87.508992     60.0000  512.3292      0.0       39.0    0.92    80.0
# 2       21.179196     15.0458   73.5000      0.0       29.0    0.67    70.0
# 3       13.302889      8.0500   69.5500      0.0       24.0    0.17    74.0
#
#
#        range_Age
# Pclass
# 1          79.08
# 2          69.33
# 3          73.83

# %%
df.groupby(['Pclass','Embarked']).Fare.median()
# Out:
# Pclass  Embarked
# 1       C           76.7292
#         Q           90.0000
#         S           52.0000
# 2       C           15.3146
#         Q           12.3500
#         S           15.3750
# 3       C            7.8958
#         Q            7.7500
#         S            8.0500
# Name: Fare, dtype: float64

# %% [markdown]
# # Crosstabs

# %%
#crosstab on Sex and Pclass
pd.crosstab(df.Sex,df.Pclass)
# Out:
# Pclass    1    2    3
# Sex
# female  144  106  216
# male    179  171  493

# %%
pd.crosstab(df['Sex'],df['Pclass']).plot(kind='bar')

# %% [markdown]
# # Pivots

# %%
#pivot table
df.pivot_table(index='Sex',columns='Pclass',values='Age',aggfunc='mean')
# Out:
# Pclass          1          2          3
# Sex
# female  37.037594  27.499223  22.185329
# male    41.029272  30.815380  25.962264

# %% [markdown]
# #### We can do this with the groupby as well

# %%
df.groupby(['Sex','Pclass']).Age.mean()
# Out:
# Sex     Pclass
# female  1         37.037594
#         2         27.499223
#         3         22.185329
# male    1         41.029272
#         2         30.815380
#         3         25.962264
# Name: Age, dtype: float64

# %%
#for showing in a tabluar form use  'unstack()'
df.groupby(['Sex','Pclass']).Age.mean().unstack()
# Out:
# Pclass          1          2          3
# Sex
# female  37.037594  27.499223  22.185329
# male    41.029272  30.815380  25.962264

# %% [markdown]
# # Data Mungin:Working with missing values

# %%
df.info()#for detecting missing value if any
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1307 non-null object
# Fare        1308 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 162.7+ KB

# %% [markdown]
# ## Feature:Embarked

# %%
#extract rows with Embraked as Null
df[df['Embarked'].isnull()]
# Out:
#               Age Cabin Embarked  Fare  \
# PassengerId
# 62           38.0   B28      NaN  80.0
# 830          62.0   B28      NaN  80.0
#
#                                                   Name  Parch  Pclass     Sex  \
# PassengerId
# 62                                 Icard, Miss. Amelie      0       1  female
# 830          Stone, Mrs. George Nelson (Martha Evelyn)      0       1  female
#
#              SibSp  Survived  Ticket
# PassengerId
# 62               0         1  113572
# 830              0         1  113572

# %% [markdown]
# ## Solving missing value problem of Embraked feature
# - Firstly find most common embraked point

# %%
#Finding most common embarked point
df['Embarked'].value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %% [markdown]
# ###  From before cell we see that most common embarked point is 'S' so we can fill the missing value with 'S'

# %%
 #which embarked point has most number of survivals  
pd.crosstab(df[df['Survived'] !=-888].Survived,df['Embarked'])
# Out:
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  217

# %%
#impute the missing value wiht 's'
#df.loc[df.Embarked.isnull(),'Embarked']= 'S'
#df.Embarked.fillna('S',inplace=True)

# %% [markdown]
# ### Option 2: Explore the fare of each class for each embarked point

# %%
df.groupby(['Pclass','Embarked']).Fare.median()
# Out:
# Pclass  Embarked
# 1       C           76.7292
#         Q           90.0000
#         S           52.0000
# 2       C           15.3146
#         Q           12.3500
#         S           15.3750
# 3       C            7.8958
#         Q            7.7500
#         S            8.0500
# Name: Fare, dtype: float64

# %%
df.pivot_table(index='Pclass',columns='Embarked',values='Fare',aggfunc='median')
# Out:
# Embarked        C      Q       S
# Pclass
# 1         76.7292  90.00  52.000
# 2         15.3146  12.35  15.375
# 3          7.8958   7.75   8.050

# %%
df.groupby(['Sex','Survived','Embarked']).Fare.median().unstack()
# Out:
# Embarked               C       Q        S
# Sex    Survived
# female -888      58.5750  7.7500  21.0000
#         0        14.4583  7.7500  20.2125
#         1        69.3000  7.8292  26.0000
# male   -888      18.6292  7.7500  13.0000
#         0        15.0479  7.7500   9.5000
#         1        30.5000  7.7500  26.0000

# %%
# replace the missing value with 'C'
df.Embarked.fillna('C',inplace=True)

# %%
df[df['Embarked'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Cabin, Embarked, Fare, Name, Parch, Pclass, Sex, SibSp, Survived, Ticket]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1308 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 162.7+ KB

# %% [markdown]
# ### Finding missing value of Fare feature

# %%
df[df['Fare'].isnull()]
# Out:
#               Age Cabin Embarked  Fare                Name  Parch  Pclass  \
# PassengerId
# 1044         60.5   NaN        S   NaN  Storey, Mr. Thomas      0       3
#
#               Sex  SibSp  Survived Ticket
# PassengerId
# 1044         male      0      -888   3701

# %%
df.groupby(['Embarked','Pclass']).Fare.median().unstack()
# Out:
# Pclass          1        2       3
# Embarked
# C         78.2667  15.3146  7.8958
# Q         90.0000  12.3500  7.7500
# S         52.0000  15.3750  8.0500

# %%
Fare_median=df.loc[(df.Pclass==3) & (df.Embarked=='S'),'Fare'].median()
print(Fare_median)
# Out:
# 8.05

# %%
df.Fare.fillna(Fare_median,inplace=True)

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Cabin, Embarked, Fare, Name, Parch, Pclass, Sex, SibSp, Survived, Ticket]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1309 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 162.7+ KB

# %% [markdown]
# ### Solving missing value problem for Feature:Age

# %%
df[df['Age'].isnull()]
# Out:
#              Age  Cabin Embarked      Fare  \
# PassengerId
# 6            NaN    NaN        Q    8.4583
# 18           NaN    NaN        S   13.0000
# 20           NaN    NaN        C    7.2250
# 27           NaN    NaN        C    7.2250
# 29           NaN    NaN        Q    7.8792
# 30           NaN    NaN        S    7.8958
# 32           NaN    B78        C  146.5208
# 33           NaN    NaN        Q    7.7500
# 37           NaN    NaN        C    7.2292
# 43           NaN    NaN        C    7.8958
# 46           NaN    NaN        S    8.0500
# 47           NaN    NaN        Q   15.5000
# 48           NaN    NaN        Q    7.7500
# 49           NaN    NaN        C   21.6792
# 56           NaN    C52        S   35.5000
# 65           NaN    NaN        C   27.7208
# 66           NaN    NaN        C   15.2458
# 77           NaN    NaN        S    7.8958
# 78           NaN    NaN        S    8.0500
# 83           NaN    NaN        Q    7.7875
# ...

# %%
#Set maximun number of row to be displayed
pd.options.display.max_rows=15

# %%
df[df['Age'].isnull()]
# Out:
#              Age Cabin Embarked      Fare  \
# PassengerId
# 6            NaN   NaN        Q    8.4583
# 18           NaN   NaN        S   13.0000
# 20           NaN   NaN        C    7.2250
# 27           NaN   NaN        C    7.2250
# 29           NaN   NaN        Q    7.8792
# 30           NaN   NaN        S    7.8958
# 32           NaN   B78        C  146.5208
# ...          ...   ...      ...       ...
# 1274         NaN   NaN        S   14.5000
# 1276         NaN   NaN        S   12.8750
# 1300         NaN   NaN        Q    7.7208
# 1302         NaN   NaN        Q    7.7500
# 1305         NaN   NaN        S    8.0500
# 1308         NaN   NaN        S    8.0500
# 1309         NaN   NaN        C   22.3583
#
#                                                        Name  Parch  Pclass  \
# PassengerId
# 6                                          Moran, Mr. James      0       3
# 18                             Williams, Mr. Charles Eugene      0       2
# ...

# %% [markdown]
# #### Option:01 replace all missing age with mean value

# %%
df['Age'].plot(kind='hist',bins=20,color='m')

# %%
df['Age'].mean()
# Out:
# 29.881137667304014

# %% [markdown]
# ### Issues: There are some outliers 70 ,80 which affect the mean value

# %%
#replace missing age with mean value
#df.Age.fillna(df.Age.mean(),inplace=True)

# %%
df.groupby('Sex').Age.median()
# Out:
# Sex
# female    27.0
# male      28.0
# Name: Age, dtype: float64

# %%
df.Age.plot(kind='box')

# %%
df[df.Age.notnull()].boxplot('Age','Sex')

# %% [markdown]
# #### From above cell we see that we get simillar type of male and female box.So this is not good idea to fill missing age considering Sex.
#
# - akhon amra jodi male and female age alada alada group kore median ber kore missing age filup kore chai then following cell will be followed.Thats means all male age gulor median ber kore male age fill up korbe simillarly female .....

# %%
#replace:
age_sex_median=df.groupby('Sex').Age.transform('median')
print(age_sex_median)
#df.Age.fillna(age_sexage_sex_median,inplace=True)
# Out:
# PassengerId
# 1       28.0
# 2       27.0
# 3       27.0
# 4       27.0
# 5       28.0
# 6       28.0
# 7       28.0
#         ...
# 1303    27.0
# 1304    27.0
# 1305    28.0
# 1306    27.0
# 1307    28.0
# 1308    28.0
# 1309    28.0
# Name: Age, Length: 1309, dtype: float64

# %% [markdown]
# ### Option 3: replace with median age of Pclass

# %%
df[df.Age.notnull()].boxplot('Age','Pclass')

# %%
#replace
pclass_age_median=df.groupby('Pclass').Age.transform('median')
print(pclass_age_median)
#df.Age.fillna(pclass_age_median,inplace=True)
# Out:
# PassengerId
# 1       24.0
# 2       39.0
# 3       24.0
# 4       39.0
# 5       24.0
# 6       24.0
# 7       39.0
#         ...
# 1303    39.0
# 1304    24.0
# 1305    24.0
# 1306    39.0
# 1307    24.0
# 1308    24.0
# 1309    24.0
# Name: Age, Length: 1309, dtype: float64

# %% [markdown]
# ### Option 4 : replace with median age of title

# %%
df.Name
# Out:
# PassengerId
# 1                                 Braund, Mr. Owen Harris
# 2       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                  Heikkinen, Miss. Laina
# 4            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                Allen, Mr. William Henry
# 6                                        Moran, Mr. James
# 7                                 McCarthy, Mr. Timothy J
#                               ...
# 1303      Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1304                       Henriksson, Miss. Jenny Lovisa
# 1305                                   Spector, Mr. Woolf
# 1306                         Oliva y Ocana, Dona. Fermina
# 1307                         Saether, Mr. Simon Sivertsen
# 1308                                  Ware, Mr. Frederick
# 1309                             Peter, Master. Michael J
# Name: Name, Length: 1309, dtype: object

# %%
#Function to extract the title from the Name such as Mr,Mrs, Miss etc
def GetTitle(name):
    first_name_with_title=name.split(',')[1]
    title=first_name_with_title.split('.')[0]
    title=title.strip().lower()
    return title

# %%
df.Name.map(GetTitle)
# Out:
# PassengerId
# 1           mr
# 2          mrs
# 3         miss
# 4          mrs
# 5           mr
# 6           mr
# 7           mr
#          ...
# 1303       mrs
# 1304      miss
# 1305        mr
# 1306      dona
# 1307        mr
# 1308        mr
# 1309    master
# Name: Name, Length: 1309, dtype: object

# %%
df.Name.map(GetTitle).unique()
# Out:
# array(['mr', 'mrs', 'miss', 'master', 'don', 'rev', 'dr', 'mme', 'ms',
#        'major', 'lady', 'sir', 'mlle', 'col', 'capt', 'the countess',
#        'jonkheer', 'dona'], dtype=object)

# %%
#Function to extract the title from the name
def GetTitle(name):
    title_group={'mr' : 'Mr',
                 'mrs': 'Mrs',
                 'miss': 'Miss',
                 'master': 'Master',
                 'don' : 'Sir',
                 'rev' : 'Sir',
                 'dr' : 'Officer',
                 'mme': 'Mrs',
                 'ms' : 'Mrs',
                 'major':'Officer',
                 'lady':'Lady',
                 'sir': 'Sir',
                 'mlle':'Miss',
                 'col':'Officer',
                 'capt':'Officer',
                 'the countess': 'Lady',
                 'jonkheer':'Sir',
                 'dona':'Lady'
                 
    }
    first_name_with_title=name.split(',')[1]
    title=first_name_with_title.split('.')[0]
    title=title.strip().lower()
    return title_group[title]

# %%
#create title feature 
df['Title']=df.Name.map(lambda x:GetTitle(x))

# %%
df['Title']
# Out:
# PassengerId
# 1           Mr
# 2          Mrs
# 3         Miss
# 4          Mrs
# 5           Mr
# 6           Mr
# 7           Mr
#          ...
# 1303       Mrs
# 1304      Miss
# 1305        Mr
# 1306      Lady
# 1307        Mr
# 1308        Mr
# 1309    Master
# Name: Title, Length: 1309, dtype: object

# %%
df.head()
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
#
#                 Sex  SibSp  Survived            Ticket Title
# PassengerId
# 1              male      1         0         A/5 21171    Mr
# 2            female      1         1          PC 17599   Mrs
# ...

# %%
#box plot of Age with title
df[df.Age.notnull()].boxplot('Age','Title')

# %% [markdown]
# #### From the above figure we can say that title is very good candidate to fill missing age.

# %%
#replace missing values
title_age_median=df.groupby('Title').Age.transform('median')
df.Age.fillna(title_age_median,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 12 columns):
# Age         1309 non-null float64
# Cabin       295 non-null object
# Embarked    1309 non-null object
# Fare        1309 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# Title       1309 non-null object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 172.9+ KB

# %% [markdown]
# # Working with Outliers

# %% [markdown]
# ## Age

# %%
#using histogram
df.Age.plot(kind='hist',bins=20,color='c')

# %%
df.loc[df.Age>70,]
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 97           71.0    A5        C  34.6542
# 117          70.5   NaN        Q   7.7500
# 494          71.0   NaN        C  49.5042
# 631          80.0   A23        S  30.0000
# 852          74.0   NaN        S   7.7750
# 988          76.0   C46        S  78.8500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 97                                   Goldschmidt, Mr. George B      0       1
# 117                                       Connors, Mr. Patrick      0       3
# 494                                    Artagaveytia, Mr. Ramon      0       1
# 631                       Barkworth, Mr. Algernon Henry Wilson      0       1
# 852                                        Svensson, Mr. Johan      0       3
# 988          Cavendish, Mrs. Tyrell William (Julia Florence...      0       1
#
#                 Sex  SibSp  Survived    Ticket Title
# PassengerId
# ...

# %% [markdown]
# ## Fare

# %%
df.Fare.plot(kind='hist',bins=20,color='c')

# %%
df.Fare.plot(kind='box')

# %%
df.loc[df.Fare==df.Fare.max(),]
# Out:
#               Age        Cabin Embarked      Fare  \
# PassengerId
# 259          35.0          NaN        C  512.3292
# 680          36.0  B51 B53 B55        C  512.3292
# 738          35.0         B101        C  512.3292
# 1235         58.0  B51 B53 B55        C  512.3292
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 259                                           Ward, Miss. Anna      0       1
# 680                         Cardeza, Mr. Thomas Drake Martinez      1       1
# 738                                     Lesurer, Mr. Gustave J      0       1
# 1235         Cardeza, Mrs. James Warburton Martinez (Charlo...      1       1
#
#                 Sex  SibSp  Survived    Ticket Title
# PassengerId
# 259          female      0         1  PC 17755  Miss
# 680            male      0         1  PC 17755    Mr
# 738            male      0         1  PC 17755    Mr
# 1235         female      0      -888  PC 17755   Mrs

# %%
#try some transform to reduce the skewness
LogFare=np.log(df.Fare + 1.0) #Adding 1 to accomodate zero fares:log(0) is not defined as some fare has 0 value

# %%
#histogram of LogFare
LogFare.plot(kind='hist',color='c',bins=20)

# %%
#binning
pd.qcut(df.Fare,4) #it is quantitle based binning 4 is number of bin
# Out:
# PassengerId
# 1         (-0.001, 7.896]
# 2       (31.275, 512.329]
# 3         (7.896, 14.454]
# 4       (31.275, 512.329]
# 5         (7.896, 14.454]
# 6         (7.896, 14.454]
# 7       (31.275, 512.329]
#               ...
# 1303    (31.275, 512.329]
# 1304      (-0.001, 7.896]
# 1305      (7.896, 14.454]
# 1306    (31.275, 512.329]
# 1307      (-0.001, 7.896]
# 1308      (7.896, 14.454]
# 1309     (14.454, 31.275]
# Name: Fare, Length: 1309, dtype: category
# Categories (4, interval[float64]): [(-0.001, 7.896] < (7.896, 14.454] < (14.454, 31.275] < (31.275, 512.329]]

# %%
labels=pd.qcut(df.Fare,4,labels=['very_low','low','high','very_high'])
print(labels)
# Out:
# PassengerId
# 1        very_low
# 2       very_high
# 3             low
# 4       very_high
# 5             low
# 6             low
# 7       very_high
#           ...
# 1303    very_high
# 1304     very_low
# 1305          low
# 1306    very_high
# 1307     very_low
# 1308          low
# 1309         high
# Name: Fare, Length: 1309, dtype: category
# Categories (4, object): [very_low < low < high < very_high]

# %%
labels.value_counts().plot(kind='hist',color='c')

# %%
#creating fare bin features
df['Fare_Bin']=pd.qcut(df.Fare,4,labels=['very_low','low','high','very_high'])

# %%
df.head(4)
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
#
#                 Sex  SibSp  Survived            Ticket Title   Fare_Bin
# PassengerId
# 1              male      1         0         A/5 21171    Mr   very_low
# 2            female      1         1          PC 17599   Mrs  very_high
# 3            female      0         1  STON/O2. 3101282  Miss        low
# ...

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Feature : Age State (Adult of Child)
# <p>As we know from title movie child had more priority for saving life</p>

# %%
#AgeState based on Age
df['AgeState']=np.where(df['Age']>=18,'Adult','Child')

# %%
#AgeState value counts
df['AgeState'].value_counts()
# Out:
# Adult    1147
# Child     162
# Name: AgeState, dtype: int64

# %%
pd.crosstab(df[df.Survived !=-888].Survived,df[df.Survived !=-888].AgeState)
# Out:
# AgeState  Adult  Child
# Survived
# 0           495     54
# 1           279     63

# %% [markdown]
# # Feature : FamilySize

# %%
#Family : Adding Parents with Siblings
df['FamilySize']=df.Parch + df.SibSp + 1  # 1 for self

# %%
df['FamilySize']
# Out:
# PassengerId
# 1       2
# 2       2
# 3       1
# 4       2
# 5       1
# 6       1
# 7       1
#        ..
# 1303    2
# 1304    1
# 1305    1
# 1306    1
# 1307    1
# 1308    1
# 1309    3
# Name: FamilySize, Length: 1309, dtype: int64

# %%
df.FamilySize.plot(kind='hist')

# %%
df.loc[df.FamilySize==df.FamilySize.max(),['Name','Survived','FamilySize','Ticket']]
# Out:
#                                           Name  Survived  FamilySize    Ticket
# PassengerId
# 160                 Sage, Master. Thomas Henry         0          11  CA. 2343
# 181               Sage, Miss. Constance Gladys         0          11  CA. 2343
# 202                        Sage, Mr. Frederick         0          11  CA. 2343
# 325                   Sage, Mr. George John Jr         0          11  CA. 2343
# 793                    Sage, Miss. Stella Anna         0          11  CA. 2343
# 847                   Sage, Mr. Douglas Bullen         0          11  CA. 2343
# 864          Sage, Miss. Dorothy Edith "Dolly"         0          11  CA. 2343
# 1080                           Sage, Miss. Ada      -888          11  CA. 2343
# 1234                     Sage, Mr. John George      -888          11  CA. 2343
# 1252               Sage, Master. William Henry      -888          11  CA. 2343
# 1257            Sage, Mrs. John (Annie Bullen)      -888          11  CA. 2343

# %%
pd.crosstab(df[df.Survived !=-888].Survived,df[df.Survived !=-888].FamilySize)
# Out:
# FamilySize   1   2   3   4   5   6   7   8   11
# Survived
# 0           374  72  43   8  12  19   8   6   7
# 1           163  89  59  21   3   3   4   0   0

# %% [markdown]
# # Feature : IsMother

# %%
#A lady aged more than 18 who has at lest one child (Parch>0) and is married (not Miss)
df['IsMother']=np.where(((df.Sex=='female') & (df.Parch>0) & (df.Age>18) & (df.Title !='Miss')),1,0)

# %%
pd.crosstab(df[df.Survived !=-888].Survived,df[df.Survived !=-888].IsMother)
# Out:
# IsMother    0   1
# Survived
# 0         533  16
# 1         303  39

# %% [markdown]
# # Feature : Deck

# %%
#explore cabin value
df.Cabin
# Out:
# PassengerId
# 1        NaN
# 2        C85
# 3        NaN
# 4       C123
# 5        NaN
# 6        NaN
# 7        E46
#         ...
# 1303     C78
# 1304     NaN
# 1305     NaN
# 1306    C105
# 1307     NaN
# 1308     NaN
# 1309     NaN
# Name: Cabin, Length: 1309, dtype: object

# %%
df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
#look at the Cabin =T
df.loc[df.Cabin=='T',]
# Out:
#               Age Cabin Embarked  Fare                          Name  Parch  \
# PassengerId
# 340          45.0     T        S  35.5  Blackwell, Mr. Stephen Weart      0
#
#              Pclass   Sex  SibSp  Survived  Ticket Title   Fare_Bin AgeState  \
# PassengerId
# 340               1  male      0         0  113784    Mr  very_high    Adult
#
#              FamilySize  IsMother
# PassengerId
# 340                   1         0

# %%
#set the value to NaN
df.loc[df.Cabin=='T','Cabin']=np.NaN

# %%
#look at the unique of Cabin again
df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44', 'A34',
#        'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14', 'B37',
#        'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38', 'B39',
#        'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68', 'B41',
#        'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48', 'E58',
# ...

# %%
#Extrack first character of Cabin string  to the deck
def get_deck(cabin):
    return np.where(pd.notnull(cabin),str(cabin)[0].upper(),'Z')
df['Deck']=df['Cabin'].map(lambda x : get_deck(x))

# %%
df.Deck.value_counts()
# Out:
# Z    1015
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# Name: Deck, dtype: int64

# %%
pd.crosstab(df[df.Survived !=-888].Survived,df[df.Survived !=-888].Deck)
# Out:
# Deck      A   B   C   D   E  F  G    Z
# Survived
# 0         8  12  24   8   8  5  2  482
# 1         7  35  35  25  24  8  2  206

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 17 columns):
# Age           1309 non-null float64
# Cabin         294 non-null object
# Embarked      1309 non-null object
# Fare          1309 non-null float64
# Name          1309 non-null object
# Parch         1309 non-null int64
# Pclass        1309 non-null int64
# Sex           1309 non-null object
# SibSp         1309 non-null int64
# Survived      1309 non-null int64
# Ticket        1309 non-null object
# Title         1309 non-null object
# Fare_Bin      1309 non-null category
# AgeState      1309 non-null object
# FamilySize    1309 non-null int64
# IsMother      1309 non-null int32
# Deck          1309 non-null object
# dtypes: category(1), float64(2), int32(1), int64(5), object(8)
# memory usage: 210.2+ KB

# %% [markdown]
#  # Categorical Feature Encoding

# %%
#sex
df['IsMale']=np.where(df.Sex=='male',1,0)

# %%
#column  Deck,Pclass,Title,AgeState
df=pd.get_dummies(df,columns=['Deck','Pclass','Title','Fare_Bin','Embarked','AgeState'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 39 columns):
# Age                   1309 non-null float64
# Cabin                 294 non-null object
# Fare                  1309 non-null float64
# Name                  1309 non-null object
# Parch                 1309 non-null int64
# Sex                   1309 non-null object
# SibSp                 1309 non-null int64
# Survived              1309 non-null int64
# Ticket                1309 non-null object
# FamilySize            1309 non-null int64
# IsMother              1309 non-null int32
# IsMale                1309 non-null int32
# Deck_A                1309 non-null uint8
# Deck_B                1309 non-null uint8
# Deck_C                1309 non-null uint8
# Deck_D                1309 non-null uint8
# Deck_E                1309 non-null uint8
# Deck_F                1309 non-null uint8
# Deck_G                1309 non-null uint8
# Deck_Z                1309 non-null uint8
# ...

# %%
df.head(5)
# Out:
#               Age Cabin     Fare  \
# PassengerId
# 1            22.0   NaN   7.2500
# 2            38.0   C85  71.2833
# 3            26.0   NaN   7.9250
# 4            35.0  C123  53.1000
# 5            35.0   NaN   8.0500
#
#                                                           Name  Parch     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0  female
# 3                                       Heikkinen, Miss. Laina      0  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0  female
# 5                                     Allen, Mr. William Henry      0    male
#
#              SibSp  Survived            Ticket  FamilySize  ...  Title_Sir  \
# PassengerId                                                 ...
# 1                1         0         A/5 21171           2  ...          0
# ...

# %% [markdown]
# # Drop and Reorder Columns

# %%
#drop column
df.drop(['Cabin','Name','Ticket','Parch','SibSp','Sex'],axis=1,inplace=True)

# %%
#reoder columns
columns=[column for column in df.columns if column !='Survived']
columns=['Survived']+ columns
df=df[columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 33 columns):
# Survived              1309 non-null int64
# Age                   1309 non-null float64
# Fare                  1309 non-null float64
# FamilySize            1309 non-null int64
# IsMother              1309 non-null int32
# IsMale                1309 non-null int32
# Deck_A                1309 non-null uint8
# Deck_B                1309 non-null uint8
# Deck_C                1309 non-null uint8
# Deck_D                1309 non-null uint8
# Deck_E                1309 non-null uint8
# Deck_F                1309 non-null uint8
# Deck_G                1309 non-null uint8
# Deck_Z                1309 non-null uint8
# Pclass_1              1309 non-null uint8
# Pclass_2              1309 non-null uint8
# Pclass_3              1309 non-null uint8
# Title_Lady            1309 non-null uint8
# Title_Master          1309 non-null uint8
# Title_Miss            1309 non-null uint8
# ...

# %% [markdown]
# # Saved Processed DataSet

# %%
#train data
df.loc[df.Survived !=-888,].to_csv('processed_train.csv')
#test data

# %%
columns=[column for column in df.columns if column !='Survived']
df.loc[df.Survived==-888,columns].to_csv('processed_test.csv')

# %% [markdown]
# # Advanced Visualization using Matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(df.Age)
# Out:
# (array([ 80.,  62., 324., 426., 189., 108.,  66.,  41.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df.Age,bins=20,color='c')
plt.show()

# %%
plt.hist(df.Age,bins=20,color='c')
plt.title("Histogram: Age")
plt.xlabel('Bins')
plt.ylabel('Counts')
plt.show()

# %%
f , ax=plt.subplots()
ax.hist(df.Age,bins=20,color='c')
ax.set_title("Histogram: Age")
ax.set_xlabel('Bins')
ax.set_ylabel("Counts")
plt.show()

# %%
#add subplots
f , (ax1,ax2)=plt.subplots(1,2,figsize=(14,3))
ax1.hist(df.Fare,bins=20,color='c')
ax1.set_title("Histogram: Age")
ax1.set_xlabel('Bins')
ax1.set_ylabel("Counts")

ax2.hist(df.Age,bins=20,color='tomato')
ax2.set_title("Histogram: Age")
ax2.set_xlabel('Bins')
ax2.set_ylabel("Counts")
plt.show()

# %%
#Adding complex subplots
f , ax_arr=plt.subplots(3,2,figsize=(14,7))
#plot 1
ax_arr[0,0].hist(df.Fare,bins=20,color='c')
ax_arr[0,0].set_title("Histogram: Age")
ax_arr[0,0].set_xlabel('Bins')
ax_arr[0,0].set_ylabel("Counts")

#plot 2
ax_arr[0,1].hist(df.Age,bins=20,color='c')
ax_arr[0,1].set_title("Histogram: Age")
ax_arr[0,1].set_xlabel('Bins')
ax_arr[0,1].set_ylabel("Counts")
#plot 3

ax_arr[1,0].boxplot(df.Fare.values)
ax_arr[1,0].set_title("Box: Age")
ax_arr[1,0].set_xlabel('Fare')
ax_arr[1,0].set_ylabel("Fare")

#plot 4
ax_arr[1,1].boxplot(df.Fare.values)
ax_arr[1,1].set_title("Histogram: Age")
ax_arr[1,1].set_xlabel('Bins')
ax_arr[1,1].set_ylabel("Counts")

#plot 5
ax_arr[2,0].scatter(df.Age,df.Fare ,color='c',alpha=.15)
ax_arr[2,0].set_title("Scatter Plot: Age vs Fare")
ax_arr[2,0].set_xlabel('Age')
ax_arr[2,0].set_ylabel("Fare")
ax_arr[2,1].axis('off')
plt.tight_layout()
plt.show()
